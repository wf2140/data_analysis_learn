# %%
simple_data = """姓名	年龄	城市	工资	部门
张三	28	北京	15000	技术部
李四	35	上海	18000	销售部
王五	42	广州	22000	市场部
赵六	25	深圳	12000	技术部
钱七	38	北京	25000	销售部
孙八	31	上海	16000	人事部
周九	29	杭州	14000	技术部
吴十	45	成都	28000	市场部
郑十一	33	北京	19000	销售部
王十二	27	深圳	13000	技术部"""

# 保存为简单TXT文件
with open('简单员工数据.txt', 'w', encoding='utf-8') as f:
    f.write(simple_data)

print("简单版TXT文件已生成：简单员工数据.txt")
# Out:
# 简单版TXT文件已生成：简单员工数据.txt

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# 创建简单的销售数据
data = {
    '订单号': ['ORD001', 'ORD002', 'ORD003', 'ORD004', 'ORD005', 'ORD006', 'ORD007', 'ORD008', 'ORD009', 'ORD010'],
    '日期': ['2024-01-05', '2024-01-12', '2024-01-18', '2024-01-25', '2024-02-03', '2024-02-10', '2024-02-15', '2024-02-22', '2024-02-28', '2024-03-05'],
    '产品': ['笔记本电脑', '手机', '平板', '笔记本电脑', '耳机', '手机', '平板', '笔记本电脑', '耳机', '手机'],
    '类别': ['电子', '电子', '电子', '电子', '配件', '电子', '电子', '电子', '配件', '电子'],
    '数量': [1, 2, 1, 1, 3, 1, 2, 1, 2, 1],
    '单价': [5500, 3200, 2800, 5200, 300, 3100, 2700, 5400, 280, 3300],
    '销售员': ['张三', '李四', '王五', '张三', '李四', '王五', '张三', '李四', '王五', '张三'],
    '地区': ['北京', '上海', '广州', '北京', '上海', '广州', '北京', '上海', '广州', '北京']
}

# 创建DataFrame
df = pd.DataFrame(data)

# 计算销售额
df['销售额'] = df['数量'] * df['单价']
# 保存为Excel文件
df.to_excel('简单销售数据.xlsx', index=False)

print("简单Excel文件已生成: 简单销售数据.xlsx")
print("\n数据预览:")
print(df)
print(f"\n数据形状: {df.shape}")
# Out:
# 简单Excel文件已生成: 简单销售数据.xlsx
#
# 数据预览:
#       订单号          日期     产品  类别  数量    单价 销售员  地区   销售额
# 0  ORD001  2024-01-05  笔记本电脑  电子   1  5500  张三  北京  5500
# 1  ORD002  2024-01-12     手机  电子   2  3200  李四  上海  6400
# 2  ORD003  2024-01-18     平板  电子   1  2800  王五  广州  2800
# 3  ORD004  2024-01-25  笔记本电脑  电子   1  5200  张三  北京  5200
# 4  ORD005  2024-02-03     耳机  配件   3   300  李四  上海   900
# 5  ORD006  2024-02-10     手机  电子   1  3100  王五  广州  3100
# 6  ORD007  2024-02-15     平板  电子   2  2700  张三  北京  5400
# 7  ORD008  2024-02-22  笔记本电脑  电子   1  5400  李四  上海  5400
# 8  ORD009  2024-02-28     耳机  配件   2   280  王五  广州   560
# 9  ORD010  2024-03-05     手机  电子   1  3300  张三  北京  3300
#
# 数据形状: (10, 9)
